# %% [markdown]
# # Area de circulo

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
np.random.seed(10)

ratio = np.random.uniform(0, 10, 10000)

area = np.pi * (ratio ** 2 )

# %%
model = Sequential([
    Dense(32, input_shape=(1, ), activation='relu' ),
    Dense(8, activation = 'relu'),
    Dense(1)
])

# %%
model.compile(
    optimizer='adam',
    loss='mean_squared_error'
)

# %%
history = model.fit(ratio, area, epochs=500, batch_size=128, verbose = 1 )
# Out:
# Epoch 1/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 605us/step - loss: 19075.7871
# Epoch 2/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 18516.6973
# Epoch 3/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - loss: 16033.1084
# Epoch 4/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - loss: 12844.6875
# Epoch 5/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 8532.8105
# Epoch 6/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - loss: 4692.4487
# Epoch 7/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 2620.2563
# Epoch 8/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 1883.7167
# Epoch 9/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 1702.6135
# Epoch 10/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 1656.1379
# Epoch 11/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 1577.3763
# Epoch 12/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - loss: 1519.2865
# Epoch 13/500
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 1484.3579
# Epoch 14/500
# ...

# %%
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de perdida")
plt.plot(history.history["loss"])

# %%
test_radios = np.array([9.0]) 
predicted_areas = model.predict(test_radios)

for r, area in zip(test_radios, predicted_areas):
    print(f"Radio: {r}, Área predicha: {area[0]:.2f}, Área real: {np.pi * r ** 2:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Radio: 9.0, Área predicha: 254.43, Área real: 254.47
